# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# load data from .npz file
datas = np.load('data.npz')
print(datas.files)
# Out:
# ['XYZ', 'S', 'lambda_', 'T_slot', 'src_model']

# %% [markdown]
# ## BS antennas' position

# %% [markdown]
# 19 antennas, on a circle, with radius = wave length.

# %%
print(datas['XYZ'])
plt.plot(datas['XYZ'][:,0], datas['XYZ'][:,1])
distance_center=((datas['XYZ'][:,0])**2+(datas['XYZ'][:,1])**2)**(1/2)
print(distance_center)
# Out:
# [[ 0.33684546  0.        ]
#  [ 0.31859424  0.10937354]
#  [ 0.2658184   0.20689476]
#  [ 0.184237    0.28199573]
#  [ 0.08269067  0.32653808]
#  [-0.02781648  0.33569496]
#  [-0.13530928  0.30847409]
#  [-0.22813922  0.24782526]
#  [-0.29624674  0.16032072]
#  [-0.33225133  0.05544294]
#  [-0.33225133 -0.05544294]
#  [-0.29624674 -0.16032072]
#  [-0.22813922 -0.24782526]
#  [-0.13530928 -0.30847409]
#  [-0.02781648 -0.33569496]
#  [ 0.08269067 -0.32653808]
#  [ 0.184237   -0.28199573]
#  [ 0.2658184  -0.20689476]
#  [ 0.31859424 -0.10937354]]
# [0.33684546 0.33684546 0.33684546 0.33684546 0.33684546 0.33684546
#  0.33684546 0.33684546 0.33684546 0.33684546 0.33684546 0.33684546
#  0.33684546 0.33684546 0.33684546 0.33684546 0.33684546 0.33684546
#  0.33684546]

# %% [markdown]
# ## time interval between the sample point

# %% [markdown]
# /delta_t=0.001s

# %%
print(datas['T_slot'])
# Out:
# 0.001

# %% [markdown]
# ## wave length of the system

# %% [markdown]
# /lambda=0.3368m

# %%
print(datas['lambda_'])
# Out:
# 0.3368454584269663

# %% [markdown]
# ## source model? //unit directions of transmitters in the cell area

# %%
print(datas['src_model'].shape)
# Out:
# (121, 2)

# %% [markdown]
# ## covariance for what?

# %%
print(datas['S'].shape)
print(datas['S'][0,:,:])
# Out:
# (10000, 19, 19)
# [[181.20819794+0.00000000e+00j  25.96555174-5.25808671e+01j
#   -27.22926625-3.25556009e+01j  -2.77988443+1.99690906e+00j
#     4.02091195+5.85010051e+00j  15.00256383-7.61092295e+00j
#    10.79896137-5.32162463e+00j -20.84691604-7.63813979e+00j
#   -13.03424197-3.23446609e+00j  21.75092445-1.02485703e+01j
#    16.08470685-3.04553375e+01j  10.52697238-2.29534250e+01j
#     5.61945906-2.90332819e+01j -36.94412447-1.69320737e+01j
#   -24.30295986+5.34025172e+01j  70.12544574+5.41951127e+01j
#    52.03060923-3.99197047e+01j -82.82465872-8.72964195e+00j
#    -7.43916927+6.85726371e+01j]
#  [ 25.96555174+5.25808671e+01j 174.93348148+6.26346991e-16j
#    53.43063964-1.91766518e+01j -14.63410268-8.38317348e+00j
#   -32.8506135 -1.76593467e+01j -12.43393801-2.98017545e+01j
#    -5.18123505-1.19907421e-01j -14.19134948+1.77116532e+01j
#     1.50082334-7.16810217e+00j  10.12682589-3.35230882e+01j
#    19.70876017-1.26588706e+01j  42.78446862-1.34013946e+01j
# ...
